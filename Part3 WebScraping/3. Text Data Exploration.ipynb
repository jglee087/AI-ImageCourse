# %% [markdown]
# #### Text Data Exploration & Visualization
# - http://www.nltk.org/api/nltk.html#nltk.text.Text

# %% [markdown]
# <br>
#
# #### 1. 가장 많이 등장하는 단어 추출하기

# %% [markdown]
# #### 1) 영화 Dark Knight 리뷰에서 많이 등장하는 명사 추출하기

# %%
import nltk
from nltk.corpus import stopwords
from collections import Counter # 글자 수 세기.

# %%
# 1) Stopwords 준비하기
stop_words = stopwords.words("english")
stop_words.append(',')
stop_words.append('.')
stop_words.append('’')
stop_words.append('”')
stop_words.append('—')

# %%
# 2) Text data 준비하기
with open('darkknight.txt', 'r', encoding="utf-8") as f:  # 읽기 형식('r')로 지정하고 인코딩은 'utf-8'로 설정한다
    lines = f.readlines()  # readlines 함수로 텍스트 파일의 내용을 읽어 리스트로 저장한다

print(len(lines))
print(type(lines))
# Out:
# 100
# <class 'list'>

# %%
# 3) Tokenizing

tokens = []
for line in lines:  # for문을 통해 각 줄에 접근한다
    tokenized = nltk.word_tokenize(line)  # 각 줄을 tokenize한다 (word_ + Tab!)

    for token in tokenized:
        if token.lower() not in stop_words:
            tokens.append(token)        

tokens
# Out:
# ["'ve",
#  'subjected',
#  'enormous',
#  'amount',
#  'hype',
#  'marketing',
#  'Dark',
#  'Knight',
#  "'ve",
#  'seen',
#  'Joker',
#  'scavenger',
#  'hunt',
#  'one',
#  'largest',
#  'viral',
#  'campaign',
#  'advertising',
#  'history',
#  'culminates',
#  'actual',
#  'release',
#  'movie.Everything',
#  "'s",
#  'said',
#  'pretty',
#  'much',
#  'spot',
#  'first',
#  'time',
#  'remember',
#  'summer',
#  'blockbuster',
#  'film',
#  'far',
#  'surpasses',
#  'hype.For',
#  'much',
#  'action',
#  'movie',
#  "'s",
#  'acting',
#  'make',
#  'great',
#  'piece',
#  'work',
#  'punch',
#  'explosion',
#  'stunt-work',
#  'great',
#  'dialog',
#  'work',
#  'actor',
#  'moments.Bale',
#  "'s",
#  'Batman',
#  'definitive',
#  'Batman',
#  'see',
#  'everything',
#  'character',
#  'finally',
#  'film',
#  'Martial',
#  'art',
#  'skill',
#  'cunning',
#  'great',
#  'tactical',
#  'thinking',
#  'forensic',
#  'application',
#  'technological',
#  'genius',
#  'advance',
#  'improve',
#  'Luscious',
#  'Fox',
#  "'s",
#  'inventions/technological',
#  'breakthrough',
#  'intimidating',
#  'personality',
#  'even',
#  'little',
#  'swashbuckling',
#  'Heath',
#  'yes',
#  'get',
#  'credit',
#  'performance',
#  'Joker',
#  'also',
#  'recognize',
#  'Jonathan',
#  'Chris',
#  'Nolan',
#  'writing',
#  'treatment',
#  'character',
#  "'s",
#  'fact',
#  'Ledger',
#  'make',
#  'Joker',
#  'menacing',
#  'Nolans',
#  'given',
#  'character',
#  'great',
#  'manifesto',
#  'drive',
#  'action',
#  'Joker',
#  "'s",
#  'stance',
#  'chaos',
#  'order',
#  'anarchy',
#  'morality',
#  'average',
#  'modern',
#  'human',
#  'make',
#  'character',
#  'interesting',
#  'psychologically',
#  'Nolans',
#  'drafted',
#  'complex',
#  'character',
#  'perfect',
#  'performance',
#  'could',
#  "'ve",
#  'pulled',
#  'something',
#  'like',
#  "'s",
#  'difficult',
#  'role',
#  "'s",
#  'Ledger',
#  "'s",
#  'performance',
#  'great.This',
#  "n't",
#  'action',
#  'movie',
#  "'s",
#  'film',
#  'explores',
#  'literary',
#  'theme',
#  'hero',
#  'villain',
#  'well',
#  'order',
#  'anarchy',
#  'Yes',
#  'listen',
#  'dialog',
#  "'s",
#  'Christopher',
#  'Nolan',
#  "'s",
#  'second',
#  'bundle',
#  'joy',
#  '``',
#  'Dark',
#  'Knight',
#  '``',
#  'EXCEEDED',
#  'expectation',
#  '!',
#  '!',
#  '!',
#  'success',
#  '2005',
#  "'s",
#  'reboot',
#  'Batman',
#  'franchise',
#  'took',
#  'already',
#  'established',
#  'expanded',
#  'amped',
#  'gave',
#  'deeper',
#  'darker',
#  'brooding',
#  'story',
#  'gripping',
#  'suspense',
#  'likely',
#  'catch',
#  'guard',
#  'several',
#  'time',
#  'throughout',
#  'Christian',
#  'Bale',
#  'delf',
#  'deeper',
#  'Batman',
#  'sworn',
#  'fight',
#  'evil',
#  'injustice',
#  'though',
#  'also',
#  'quite',
#  'reluctant',
#  'uncertain',
#  'crusade',
#  'ever',
#  'end',
#  'cleanse',
#  'inner',
#  'turmoil',
#  'fractured',
#  'soul',
#  'due',
#  'murder',
#  'beloved',
#  'parent',
#  'help',
#  'trusted',
#  'butler/ally',
#  'Alfred',
#  '(',
#  'played',
#  'superbly',
#  'Michael',
#  'Cane',
#  ')',
#  'ground',
#  'give',
#  'moral',
#  'support',
#  'keep',
#  'check',
#  'real',
#  'star',
#  'show',
#  'Heath',
#  'Ledger',
#  'Batman',
#  "'s",
#  'deadly',
#  'enemy',
#  'Joker',
#  'HONESTLY',
#  'tell',
#  ':',
#  'good',
#  'Jack',
#  'Nicholson',
#  "Batman'89",
#  'CHILD',
#  "'S",
#  'PLAY',
#  'compared',
#  'Joker',
#  'sadistic',
#  'psychotic',
#  'downright',
#  'SCARIER',
#  'PSYCHOLOGICALLY',
#  'disturbing',
#  'previous',
#  'incarnation',
#  'Clown',
#  'Prince',
#  'Crime',
#  'Ledger',
#  'give',
#  'justice',
#  'Along',
#  'original',
#  'cast',
#  'come',
#  'fresh',
#  'face',
#  'Aaron',
#  'Eckhart',
#  'Maggie',
#  'Gyllenhaal',
#  'must',
#  'say',
#  'though',
#  'liked',
#  'Katie',
#  'Holmes',
#  'Gyllenhaal',
#  'give',
#  'much',
#  'better',
#  'performance',
#  'far',
#  'cry',
#  '``',
#  'damsel-in-distress',
#  '``',
#  'stereotype',
#  '(',
#  'though',
#  "'s",
#  'little',
#  'THANKFULLY',
#  ')',
#  "'s",
#  'common',
#  'film',
#  'Bale',
#  'Gyllenhall',
#  'MUCH',
#  'better',
#  'chemistry',
#  'time',
#  'around',
#  'Holmes',
#  'Even',
#  'better',
#  'fight',
#  'sequence',
#  'vastly',
#  'improved',
#  'feature',
#  'brutal',
#  'bone',
#  'crushing',
#  'combat',
#  '``',
#  'Begins',
#  '``',
#  'addition',
#  'new',
#  'technology',
#  'Batman',
#  "'s",
#  'disposal',
#  'Also',
#  'worth',
#  'mentioning',
#  'screenwriter',
#  'Jonathan',
#  'Nolan',
#  'give',
#  'film',
#  'added',
#  'frosting',
#  'already',
#  'delicious',
#  'cake',
#  'Simply',
#  'put',
#  'Dark',
#  'Knight',
#  'totally',
#  'bad',
#  '``',
#  'Begins',
#  '``',
#  'action',
#  'great',
#  'plot',
#  'deeper',
#  'engrossing',
#  'applaud',
#  'Christopher',
#  'Nolan',
#  'Christian',
#  'Bale',
#  'especially',
#  'Heath',
#  'Ledger',
#  '(',
#  'sadly',
#  'passed',
#  'away',
#  'earlier',
#  'year',
#  ')',
#  'aboard',
#  'believing',
#  'Mr.',
#  'Nolan',
#  "'s",
#  'talent',
#  'second',
#  'installment',
#  'Although',
#  'may',
#  'feel',
#  'bit',
#  'melancholy',
#  'Ledger',
#  "'s",
#  'death',
#  'final',
#  'note',
#  'say',
#  'sincerely',
#  'heart',
#  ':',
#  'Remember',
#  'Heath',
#  'Ledger',
#  'honor',
#  'mind',
#  'heart',
#  'performance',
#  'human',
#  'father',
#  'daughter',
#  'Matilda',
#  'Ledger',
#  'May',
#  'issue',
#  'best',
#  'wish',
#  'family',
#  'friend',
#  'daughter',
#  'year',
#  'come',
#  'Remember',
#  'Honor',
#  'role',
#  'past',
#  'role',
#  'incredible',
#  'individual',
#  'talented',
#  'actor',
#  'Rest',
#  'peace',
#  'Heath',
#  'Ledger',
#  ':',
#  '4/4/1979-1/22/2008',
#  'honor',
#  'watching',
#  'TDK',
#  'screening',
#  'completely',
#  'blown',
#  'away',
#  '!',
#  "n't",
#  'best',
#  'Batman',
#  'movie',
#  'ever',
#  'made',
#  'one',
#  'best',
#  'movie',
#  'ever',
#  'made',
#  'Everything',
#  'film',
#  'excellent',
#  'one',
#  'piece',
#  'annoyance.Bale',
#  'marvel',
#  'Bruce',
#  'Wayne/Batman',
#  'Ledger',
#  'made',
#  'Joker',
#  'iconic',
#  'movie',
#  'villain',
#  'performance',
#  'belongs',
#  'top',
#  'Hopkins',
#  'Lecter',
#  'Joker',
#  'finally',
#  'portrait',
#  'properly',
#  'film',
#  'earned',
#  'place',
#  'big',
#  'boy',
#  'movie',
#  'villandom',
#  'true',
#  'Joker',
#  'every',
#  'Batman',
#  'fan',
#  'know',
#  'love',
#  'fear',
#  'Ledger',
#  'deserves',
#  'every',
#  'movie',
#  'award',
#  'known',
#  'man',
#  'brilliant',
#  'display.Nolan',
#  'made',
#  '``',
#  'always',
#  'remembered',
#  '``',
#  'movie',
#  'crownjewel',
#  'portfolio',
#  'Perfect',
#  'directing',
#  'perfect',
#  'story',
#  'perfect',
#  'balance',
#  'action',
#  'drama',
#  'everything',
#  'perfect',
#  'Even',
#  'hate',
#  'Batman',
#  'love',
#  'film',
#  "n't",
#  'something',
#  'beez',
#  'wrongz',
#  'youz',
#  '!',
#  'used',
#  'leave',
#  'theatre',
#  'seeing',
#  'highly',
#  'anticipated',
#  'movie',
#  'specifically',
#  'sequel',
#  'revved',
#  'saw',
#  'would',
#  'declare',
#  'movie',
#  'best',
#  'series',
#  'prequel',
#  '``',
#  'Star',
#  'Wars',
#  '``',
#  'film',
#  'rated',
#  'one',
#  'best',
#  'good',
#  'original',
#  '...',
#  'time',
#  'opinion',
#  'balanced',
#  'well-rounded',
#  'take',
#  'reason',
#  'steer',
#  'away',
#  'mindset',
#  '``',
#  'Dark',
#  'Knight',
#  '``',
#  '.Though',
#  'opinion',
#  'solidifying',
#  'already',
#  'seen',
#  'Warner',
#  'Bros.',
#  'screening',
#  'last',
#  'night',
#  '``',
#  'Dark',
#  'Knight',
#  '``',
#  'ably',
#  'stand',
#  'without',
#  '``',
#  'Batman',
#  'Begins',
#  '``',
#  'two',
#  'half',
#  'hour',
#  'runtime',
#  "'s",
#  'definitely',
#  'epic',
#  'movie',
#  'one',
#  'never',
#  'run',
#  'gas',
#  'delightful',
#  'addition',
#  'experience',
#  'healthy',
#  'amount',
#  'IMAX',
#  'footage',
#  'significantly',
#  'add',
#  'feel',
#  'personal',
#  'gruesome',
#  'tour',
#  'Gotham',
#  'City.Christian',
#  'Bale',
#  'play',
#  'well',
#  'rounded',
#  'Batman',
#  'Bruce',
#  'Wayne',
#  'quality',
#  'none',
#  'donned',
#  'cowl',
#  'pulled',
#  'still',
#  'remember',
#  'Bale',
#  'British',
#  'since',
#  'speaks',
#  'spot',
#  'American',
#  'accent',
#  'Bale',
#  'particular',
#  'slurring',
#  'lisp',
#  'serf',
#  'quite',
#  'well',
#  'charmingly',
#  'Bruce',
#  'Wayne',
#  'threateningly',
#  'Batman.Countering',
#  'late',
#  'Heath',
#  'Ledger',
#  'play',
#  'scary',
#  'creepy',
#  'Joker',
#  'found',
#  'impossible',
#  'chill',
#  'half',
#  'time',
#  'saw',
#  'screen',
#  'really',
#  'separate',
#  'brand',
#  'Joker',
#  'Jack',
#  'Nicholson',
#  "'s",
#  'portrayal',
#  'true',
#  'unpredictability',
#  "'s",
#  'obvious',
#  'good',
#  'guy',
#  'think',
#  'like',
#  'Joker',
#  'really',
#  'take',
#  'toll',
#  'sure',
#  "n't",
#  'easy',
#  'exactly',
#  'one',
#  'take',
#  "'s",
#  'woven',
#  'harebrained',
#  'plot',
#  'around',
#  'multiple',
#  'hostage',
#  'explosive',
#  'disappearing',
#  'parlor',
#  'trick',
#  '?',
#  'Initially',
#  'uneasy',
#  'character',
#  'Harvey',
#  'Dent',
#  'would',
#  'handled',
#  'mind',
#  'really',
#  'one',
#  'faithful',
#  'portrayal',
#  'could',
#  'found',
#  '``',
#  'Batman',
#  '``',
#  'animated',
#  'series',
#  'early',
#  '90',
#  'well',
#  'Tommy',
#  'Lee',
#  'Jones',
#  'COULD',
#  'handled',
#  '``',
#  'Batman',
#  'Forever',
#  '``',
#  'certainly',
#  'though',
#  'still',
#  'highlight',
#  'movie',
#  'Aaron',
#  'Eckhart',
#  'ably',
#  'assumes',
#  'mantle',
#  'delivering',
#  'performance',
#  'world',
#  'easily',
#  'par',
#  'Batman',
#  'animated',
#  'series.Be',
#  'known',
#  'caped',
#  'avenger',
#  'stand',
#  'good',
#  'Gotham',
#  'City',
#  'police',
#  'force',
#  'counterpart',
#  'ca',
#  "n't",
#  'represent',
#  'good',
#  'jurisdiction',
#  'procedure',
#  '...',
#  'rule',
#  'save',
#  'one',
#  'hope',
#  "'ve",
#  'seen',
#  'prelude',
#  'Dark',
#  'Knight',
#  "'s",
#  'upcoming',
#  'legendary',
#  'battle',
#  'worst',
#  'Gotham',
#  'City',
#  "'s",
#  'dark',
#  'underside',
#  '``',
#  'Dark',
#  'Knight',
#  '``',
#  'get',
#  'solid',
#  '10',
#  '10',
#  'star',
#  'must',
#  'say',
#  'excited',
#  'movie',
#  'since',
#  'instant',
#  'BATMAN',
#  'BEGINS',
#  'appeared',
#  'screen',
#  'end',
#  'first',
#  'film',
#  'always',
#  'going',
#  'good',
#  'sadly',
#  'always',
#  'going',
#  'over-hyped',
#  'advertising',
#  'warhorses.It',
#  'rare',
#  'though',
#  'movie',
#  'surpass',
#  'hype',
#  'pas',
#  'expectation',
#  'film',
#  'Nolan',
#  '(',
#  'Prestige',
#  'Begins',
#  ')',
#  'delivers',
#  'Joker',
#  'remember',
#  "'Old",
#  'Days',
#  "'",
#  'Burton',
#  'Nicholson',
#  'Instead',
#  "'re",
#  'given',
#  'psychopathic',
#  'sadist',
#  'pleasure',
#  'sheer',
#  'anarchy.All',
#  'hailing',
#  'Ledger',
#  "'s",
#  'performance',
#  'grounded',
#  'Watching',
#  'make',
#  'feel',
#  'different',
#  'chill',
#  'spine',
#  "'d",
#  'remember',
#  'film',
#  "'s",
#  'impossible',
#  'quite',
#  'literally',
#  'relate',
#  'Joker',
#  'get',
#  'inside',
#  'head',
#  'story',
#  'got',
#  'scar',
#  'make',
#  'laugh',
#  'sick',
#  'joke',
#  'make',
#  'instantly',
#  'wonder',
#  "'re",
#  'laughing.If',
#  'Ledger',
#  "n't",
#  'enough',
#  'horrify',
#  '-',
#  'wait',
#  'Harvey',
#  'Dent',
#  'Brilliantly',
#  'portrayed',
#  'Aaron',
#  'Eckhart',
#  'Gotham',
#  "'s",
#  "'fallen",
#  'White',
#  'Knight',
#  "'",
#  'Batman',
#  "'s",
#  'direct',
#  'counterpart',
#  'transformation',
#  'put',
#  'Tommy',
#  'Lee',
#  'Jones',
#  "'",
#  'portrayal',
#  'look',
#  'like',
#  'child',
#  "'s",
#  'breakfast',
#  'cartoon',
#  'Gyllenhaal',
#  'perfect',
#  'chemistry',
#  'Bale',
#  'Eckhart',
#  'Michael',
#  'Caine',
#  'Morgan',
#  'Freeman',
#  'work',
#  'well',
#  'Batman',
#  "'s",
#  "'conscience",
#  "'",
#  'course',
#  'Gary',
#  'Oldman',
#  'Lieutenant',
#  'Gordon',
#  'solid.There',
#  'major',
#  'difference',
#  'Dark',
#  'Knight',
#  'Begins',
#  'Firstly',
#  'music',
#  'extremely',
#  'disconcerted',
#  'compared',
#  "'majestic",
#  'unfinished',
#  "'",
#  'tone',
#  'Begins',
#  '-',
#  'suit',
#  'film',
#  "'s",
#  'tone',
#  ':',
#  'Anarchy',
#  'every',
#  'sense',
#  'solid',
#  'singular',
#  'villain',
#  '(',
#  'compared',
#  'many',
#  'Begins',
#  ')',
#  '-',
#  'also',
#  'lot',
#  'henchman',
#  'TDK',
#  'martial',
#  'art',
#  'direction',
#  'faster',
#  'efficient',
#  '-',
#  'mentioned',
#  'film',
#  'learning',
#  'experience.I',
#  'disappointed',
#  'role',
#  'Scarecrow',
#  ...]

# %%
#

# %%
# 4) POS Tagging - 명사 종류만 모으기

tags = nltk.pos_tag(tokens)  # tokenize한 결과를 품사 태깅한다

# tags는 단어와 품사로 저장된 tuple이다.

wordList = []

for word, tag in tags:  # for 문을 통해 각각의 (단어, 태그) 쌍에 접근
    if tag in ['NN', 'NNS', 'NNP', 'NNPS']:  # 만약 태그가 명사 종류이면:
        wordList.append(word.lower())  # 소문자로 변환한 후 리스트에 첨부한다

# %%
counts = Counter(wordList)  # 각 명사의 숫자를 센 결과를 변수에 저장한다 (Counter -> {'home': 15, '단어':출현횟수, ...})
# print(counts)

# %%
print(counts.most_common(15))  # 가장 많이 등장한 10개 명사를 출력한다 (most common words)
# Out:
# [('movie', 405), ('batman', 303), ('film', 283), ('joker', 219), ('dark', 136), ('ledger', 131), ('knight', 124), ('time', 112), ('heath', 110), ('performance', 87), ('action', 86), ('character', 76), ('nolan', 76), ('bale', 70), ('story', 51)]

# %% [markdown]
# #### 2) 영화 Dark Knight 리뷰에서 많이 등장하는 형용사 추출하기
# - ['JJ', 'JJR', 'JS']

# %%
# 1) Stopwords 준비하기
# 생략

# 2) Text data 준비하기
# 생략

# 3) Tokenizing
# 생략

# 4) POS Tagging - 형용사 종류만 모으기
tags = nltk.pos_tag(tokens)  # tokenize한 결과를 품사 태깅한다
wordList = []
for word, tag in tags:  # for 문을 통해 각각의 (단어, 태그) 쌍에 접근
    if tag in ['JJ', 'JJR', 'JS']:  # 만약 태그가 형용사 종류이면:
        wordList.append(word.lower())  # 소문자로 변환한 후 리스트에 첨부한다

counts = Counter(wordList)  # 각 형용사의 숫자를 센 결과를 변수에 저장한다 (Counter -> {'home': 15, '단어':출현횟수, ...})
# print(counts)
print(counts.most_common(10))  # 가장 많이 등장한 10개 형용사를 출력한다
# Out:
# [('good', 141), ('great', 78), ('many', 54), ('much', 52), ('comic', 43), ('real', 29), ('bad', 28), ('little', 26), ('new', 25), ('last', 22)]

# %% [markdown]
# #### 3) 영화 Dark Knight 리뷰에서 많이 등장하는 동사 추출하기
# - ['VB', 'VBD', 'VBN', 'VBP', 'VBZ']

# %%
# 1) Stopwords 준비하기
# 생략

# 2) Text data 준비하기
# 생략

# 3) Tokenizing
# 생략

# 4) POS Tagging - 동사 종류만 모으기
tags = nltk.pos_tag(tokens)  # tokenize한 결과를 품사 태깅한다
wordList = []
for word, tag in tags:  # for 문을 통해 각각의 (단어, 태그) 쌍에 접근
    if tag in ['VB', 'VBD', 'VBN', 'VBP', 'VBZ']:  # 만약 태그가 동사 종류이면:
        wordList.append(word.lower())  # 소문자로 변환한 후 리스트에 첨부한다

counts = Counter(wordList)  # 각 동사의 숫자를 센 결과를 변수에 저장한다 (Counter -> {'home': 15, '단어':출현횟수, ...})
# print(counts)
print(counts.most_common(10))  # 가장 많이 등장한 10개 동사를 출력한다
# Out:
# [('see', 59), ('get', 54), ('made', 49), ('think', 46), ('seen', 45), ('make', 45), ('say', 41), ("'ve", 37), ("'m", 32), ('thought', 30)]

# %% [markdown]
# <br>
# <br>
#
# #### 2. 영화 Dark Knight 리뷰에서 등장하는 토큰 개수 확인하기

# %%
stop_words = stopwords.words("english")
stop_words.append(',')
stop_words.append('.')
stop_words.append('’')
stop_words.append('”')
stop_words.append('—')
stop_words.append('else')
stop_words.append('$')
stop_words.append("'s")
stop_words.append("'ve")


with open('darkknight.txt', 'r', encoding="utf-8") as f:  # 읽기 형식('r')로 지정하고 인코딩은 'utf-8'로 설정한다
    lines = f.readlines()  # readlines 함수로 텍스트 파일의 내용을 읽어 리스트로 저장한다

tokens = []
for line in lines:  # for문을 통해 각 줄에 접근한다
    tokenized = nltk.word_tokenize(line)  # 각 줄을 tokenize한다
    for token in tokenized:
        if token.lower() not in stop_words:
            tokens.append(token)

# %%
corpus = nltk.Text(tokens)  ### Text를 이용!
print(corpus.tokens)
# Out:
# ['subjected', 'enormous', 'amount', 'hype', 'marketing', 'Dark', 'Knight', 'seen', 'Joker', 'scavenger', 'hunt', 'one', 'largest', 'viral', 'campaign', 'advertising', 'history', 'culminates', 'actual', 'release', 'movie.Everything', 'said', 'pretty', 'much', 'spot', 'first', 'time', 'remember', 'summer', 'blockbuster', 'film', 'far', 'surpasses', 'hype.For', 'much', 'action', 'movie', 'acting', 'make', 'great', 'piece', 'work', 'punch', 'explosion', 'stunt-work', 'great', 'dialog', 'work', 'actor', 'moments.Bale', 'Batman', 'definitive', 'Batman', 'see', 'everything', 'character', 'finally', 'film', 'Martial', 'art', 'skill', 'cunning', 'great', 'tactical', 'thinking', 'forensic', 'application', 'technological', 'genius', 'advance', 'improve', 'Luscious', 'Fox', 'inventions/technological', 'breakthrough', 'intimidating', 'personality', 'even', 'little', 'swashbuckling', 'Heath', 'yes', 'get', 'credit', 'performance', 'Joker', 'also', 'recognize', 'Jonathan', 'Chris', 'Nolan', 'writing', 'treatment', 'character', 'fact', 'Ledger', 'make', 'Joker', 'menacing', 'Nolans', 'given', 'character', 'great', 'manifesto', 'drive', 'action', 'Joker', 'stance', 'chaos', 'order', 'anarchy', 'morality', 'average', 'modern', 'human', 'make', 'character', 'interesting', 'psychologically', 'Nolans', 'drafted', 'complex', 'character', 'perfect', 'performance', 'could', 'pulled', 'something', 'like', 'difficult', 'role', 'Ledger', 'performance', 'great.This', "n't", 'action', 'movie', 'film', 'explores', 'literary', 'theme', 'hero', 'villain', 'well', 'order', 'anarchy', 'Yes', 'listen', 'dialog', 'Christopher', 'Nolan', 'second', 'bundle', 'joy', '``', 'Dark', 'Knight', '``', 'EXCEEDED', 'expectation', 'success', '2005', 'reboot', 'Batman', 'franchise', 'took', 'already', 'established', 'expanded', 'amped', 'gave', 'deeper', 'darker', 'brooding', 'story', 'gripping', 'suspense', 'likely', 'catch', 'guard', 'several', 'time', 'throughout', 'Christian', 'Bale', 'delf', 'deeper', 'Batman', 'sworn', 'fight', 'evil', 'injustice', 'though', 'also', 'quite', 'reluctant', 'uncertain', 'crusade', 'ever', 'end', 'cleanse', 'inner', 'turmoil', 'fractured', 'soul', 'due', 'murder', 'beloved', 'parent', 'help', 'trusted', 'butler/ally', 'Alfred', 'played', 'superbly', 'Michael', 'Cane', 'ground', 'give', 'moral', 'support', 'keep', 'check', 'real', 'star', 'show', 'Heath', 'Ledger', 'Batman', 'deadly', 'enemy', 'Joker', 'HONESTLY', 'tell', ':', 'good', 'Jack', 'Nicholson', "Batman'89", 'CHILD', 'PLAY', 'compared', 'Joker', 'sadistic', 'psychotic', 'downright', 'SCARIER', 'PSYCHOLOGICALLY', 'disturbing', 'previous', 'incarnation', 'Clown', 'Prince', 'Crime', 'Ledger', 'give', 'justice', 'Along', 'original', 'cast', 'come', 'fresh', 'face', 'Aaron', 'Eckhart', 'Maggie', 'Gyllenhaal', 'must', 'say', 'though', 'liked', 'Katie', 'Holmes', 'Gyllenhaal', 'give', 'much', 'better', 'performance', 'far', 'cry', '``', 'damsel-in-distress', '``', 'stereotype', 'though', 'little', 'THANKFULLY', 'common', 'film', 'Bale', 'Gyllenhall', 'MUCH', 'better', 'chemistry', 'time', 'around', 'Holmes', 'Even', 'better', 'fight', 'sequence', 'vastly', 'improved', 'feature', 'brutal', 'bone', 'crushing', 'combat', '``', 'Begins', '``', 'addition', 'new', 'technology', 'Batman', 'disposal', 'Also', 'worth', 'mentioning', 'screenwriter', 'Jonathan', 'Nolan', 'give', 'film', 'added', 'frosting', 'already', 'delicious', 'cake', 'Simply', 'put', 'Dark', 'Knight', 'totally', 'bad', '``', 'Begins', '``', 'action', 'great', 'plot', 'deeper', 'engrossing', 'applaud', 'Christopher', 'Nolan', 'Christian', 'Bale', 'especially', 'Heath', 'Ledger', 'sadly', 'passed', 'away', 'earlier', 'year', 'aboard', 'believing', 'Mr.', 'Nolan', 'talent', 'second', 'installment', 'Although', 'may', 'feel', 'bit', 'melancholy', 'Ledger', 'death', 'final', 'note', 'say', 'sincerely', 'heart', ':', 'Remember', 'Heath', 'Ledger', 'honor', 'mind', 'heart', 'performance', 'human', 'father', 'daughter', 'Matilda', 'Le ...

# %%
print(len(corpus.tokens))  # 전체 token의 개수를 출력한다
print(len(set(corpus.tokens)))  # unique한 token의 개수를 출력한다 
# set은 중복된 자료를 허용하지 않는다.
# Out:
# 17517
# 4641

# %% [markdown]
# <br>
# <br>
#
# #### 3. 토큰의 등장 횟수 시각화하기

# %%
a=re.match('^[a-zA-Z]+','aZp!aa')
print(a)
# Out:
# <re.Match object; span=(0, 3), match='aZp'>

# %%
import matplotlib.pyplot as plt
import re # 정규표현식

stop_words = stopwords.words("english")
stop_words.append('else')

with open('darkknight.txt', 'r', encoding="utf-8") as f:  # 읽기 형식('r')로 지정하고 인코딩은 'utf-8'로 설정한다
    lines = f.readlines()  # readlines 함수로 텍스트 파일의 내용을 읽어 리스트로 저장한다
    #f.close()  # 파일을 닫는다
    
tokens = []
for line in lines:  # for문을 통해 각 줄에 접근한다
    tokenized = nltk.word_tokenize(line)  # 각 줄을 tokenize한다
    for token in tokenized: # 각 Token이
        if token.lower() not in stop_words: # Stopwords 리스트에 포함되어 있지 않으며,
            if re.match('^[a-zA-Z]+', token): # 특수 기호에 해당하지 않을 경우,
                tokens.append(token) # Token list 에 추가해준다.

# %%
corpus = nltk.Text(tokens) # corpus 말 뭉치(텍스트를 모아둔 가방)

# %%
plt.figure(figsize=(10, 3)) 
plt.title('Top 25 Words',fontsize=30)

corpus.plot(25) # 25개까지만 확인, "plot" the data

# %% [markdown]
# <br>
# <br>
#
# #### 4. 문맥 상 유사한 단어 출력하기

# %%
import re

with open('darkknight.txt', 'r', encoding="utf-8") as f:  # 읽기 형식('r')로 지정하고 인코딩은 'utf-8'로 설정한다
    lines = f.readlines()  # readlines 함수로 텍스트 파일의 내용을 읽어 리스트로 저장한다

tokens = []
for line in lines:  # for문을 통해 각 줄에 접근한다
    tokenized = nltk.word_tokenize(line)  # 각 줄을 tokenize한다
    for token in tokenized: # 각 Token이
        if token.lower() not in stop_words: # Stopwords 리스트에 포함되어 있지 않으며,
            if re.match('^[a-zA-Z]+', token): # 특수 기호에 해당하지 않을 경우,
                tokens.append(token) # Token list 에 추가해준다.

corpus = nltk.Text(tokens)

# %%
print('Similar words : ')
corpus.similar('batman') # 유사한 단어들 (similar words)
# Out:
# Similar words :
# superhero film action movie character better iconic seen acting actor
# heath performance modern difficult villain second end good come best

# %% [markdown]
# <br>
# <br>
#
# #### 5. 텍스트의 연어(collocation) 출력하기

# %%
with open('darkknight.txt', 'r', encoding="utf-8") as f:  # 읽기 형식('r')로 지정하고 인코딩은 'utf-8'로 설정한다
    lines = f.readlines()  # readlines 함수로 텍스트 파일의 내용을 읽어 리스트로 저장한다
    f.close()  # 파일을 닫는다
    
tokens = []
for line in lines:  # for문을 통해 각 줄에 접근한다
    tokenized = nltk.word_tokenize(line)  # 각 줄을 tokenize한다
    for token in tokenized: # 각 Token이
        if token.lower() not in stop_words: # Stopwords 리스트에 포함되어 있지 않으며,
            if re.match('^[a-zA-Z]+', token): # 특수 기호에 해당하지 않을 경우,
                tokens.append(token) # Token list 에 추가해준다.
        
corpus = nltk.Text(tokens)

# %%
print('Collocation')
corpus.collocations() # co-location
# Out:
# Collocation
# Dark Knight; Heath Ledger; Christian Bale; comic book; Harvey Dent;
# Christopher Nolan; Bruce Wayne; Aaron Eckhart; Morgan Freeman; Gary
# Oldman; Batman Begins; Two Face; Gotham City; Maggie Gyllenhaal;
# Rachel Dawes; Michael Caine; special effect; Tim Burton; Jack
# Nicholson; dark knight
